# %%
import pandas as pd
from collections import Counter
from scipy.stats import chi2_contingency
import numpy as np

# Load your Excel file (replace the path with your actual file)
file_path = '/content/sample_data/nonexperts_EN_clean.xlsx'
df = pd.read_excel(file_path)

# Example correct answers dictionary
correct_answers = {
    "Brocolli_img": [
        "Brocolli",
        "Broccoli",
        "Broccoli",
        "Brocoli",
        "Broccoli",
        "Broccoli",
        "Broccoli",
        "Brocoli",
        "Broccoli",
        "Broccoli",
        "broccoli",
        "broccoli",
        "Brócoli",
        "Broccoli",
        "broccoli",
        "Broccoli",
        "Broccoli",
        "Brocoli",
        "Broccoli",
        "Broccoli",
        "broccoli",
    ],
    "Carrot_img": [

        "Carrots",
        "Carrot",
        "carrot"
        "Carrots",
        "Carrots",
        "Carrots",
        "Carrots",
        "carrots",
        "carrots",
        "Carrots",
        "carrots",
        "Carrots",
        "Carrots",
        "Carrots",

    ],
    "Cauliflower_img": [
        "Colliflower",
        "Couliflower",
        "Cauliflower",
        "Cauliflowers",
        "Cauliflower",
        "Cauliflower",
        "Cauliflower",
        "Cauliflower",
        "Cauliflower",
        "cauliflower",
        "cauliflower",
        "Cauliflower",
        "cauliflower",
        "Califlower",
        "Cauliflower",
        "Cauliflower",
        "Cauliflower",
        "Cauliflower",
    ],
    "Chicken_Breast_img": [

        "Chicken Breast",


        "Chicken breast",

        "Chicken breast",
        "Chicken breast",
        "Chicken breast",
        "Chicken breast",
    ],
    "Apple_img": [
        "Apple",
        "Apple",
        "Apple",
        "apples",
        "Apples"


        "Apple",


        "apple",


        "Apple",
        "Apple",



    ],
    "Ham_slice_img": [
        "Ham",

        "Ham",
        "Ham",
        "Ham",

        "Ham",
        "hams",
        "Ham",
        "Ham",
        "Ham",

        "ham",
        "Ham",

        "Ham",
        "Ham",
        "Ham",

    ],
    "McIntosh_Apple_img": [
        "Apple",
        "Apple",
        "Apple",

        "Apple",
        "apples",

        "Apple",

        "Apple",
        "Apple",
        "apple",
        "apple",

        "Apple",
        "Apple",

        "Apple",

        "Apple",
    ],
    "moon_drop_grape_img": [

        "Grape",


        "Grape",


        "Grapes",


        "Grapes",




        "Grapes",

    ],
    "pork_sausage_img": [
        "Sausage",
        "Sausage",
        "Sausages",
        "sausage",

        "Sausage",
        "Sausage",



        "Sausage",
        "Sausage",
        "sausages",
        "sausages",

        "sausages",
        "Sausage",
        "Sausage",

        "Sausages",

        "Sausages",
    ],
    "red_globe_grape_img": [
        "Grape",
        "Grapes",
        "Grapes",
        "Grapes",

        "Grape",
        "Grapes",


        "Grapes",
        "Grapes",

        "grapes",
        "Grapes",

        "Grapes",
        "Grapes",

        "Grapes",


    ],
    "ribeye_steak_img": [
        "Steak",

        "Steak",

        "Steak",

        "Steak",
        "Steak",

        "Steak",

        "Steak",


        "Steak",

    ],
    "salmon_fillet_img": [
        "Salmon",
        "Salmon",
        "Salmon",
        "Salmon",

        "Salmon",
        "Salmon",

        "Salmon",
        "Salmon",

        "salmon",
        "salmon",

        "Salmon",

        "Salmon",

    ],
    "sweet_potato_img": [

        "Sweet potato",
        "Sweet Potato",
        "Sweet potato",
        "Sweet potatoe",

        "Sweet potatoe",

        "Sweet potato",
        "Sweet potatoes",

        "sweet potatoes",
        "Sweet potatoes",
        "Seet potatoes",

        "Sweet potato",

        "Sweet Potato",
        "Sweet potato",
        "Sweet potatoe",


    ],
    "t_bone_steak_img": [
        "T bone steak",


        "Mmmmmmm t bone steak",

        "T-bone steak",

        "T-bone steak",
        "T bone steak",




        "Raw T Bone Steak",


    ],
    "tuna_steak_img": [


        "Tuna",

        "Tuna",
        "Tuna?",


        "Tuna",
        "Tuna",


        "Tuna",

        "Tuna",
        "Tuna",
        "Tuna",


    ],
    "turkey_breast_img": [

        "Cooked chicken",

        "Cooked chicken breast",
        "cooked chicken",

        "Cooked chicken",

    ],
    "bass_trombone_img": [
        "Trombone",
        "Trombone",
        "Trombone",

        "Trombone",


        "Trombon",
        "Trombone",

        "trombone",



        "Trombone",

        "Trombone",

        "Trombone",
    ],
    "bell_img": [
        "Bell",
        "Bell",
        "Bell",
        "Bell",

        "Bell",

        "Bell",
        "Bell",
        "Bell",
        "bell",
        "bell",
        "Bell",

        "bell",
        "Bell",

        "Bell",
        "Bell",

    ],
    "bongo_drums_img": [

        "Bongos",

        "Bongos",

        "Bongos",

        "Bongos",

        "bongos",

        "Bongos",


        "Bongos",


        "Bongos",


    ],
    "castanets_img": [
        "Wood",
        "Castanet",

        "Castanets",

        "Castanets???",
        "Castanets",
        "Castañuelas",



        "castanets",
        "Castañuelas",
        "Castañuelas",


        "Castanets",
        "Castanets",

    ],
    "clarinet_img": [

        "Clarinet",
        "Clarinet",
        "Clarinet",

        "Clarinet",
        "Clarinet",


        "Clarinet",

        "clarinet",
        "clarinet",
        "Clarinete",


        "Clarinet",
        "Clarinet",
        "Clarinet",

    ],
    "cornet_img": [
        "Ttumprt",
        "Trumpet",
        "Trumpet",

        "Trumpet",

        "Trumpet",
        "Trumpet",
        "trumpet",
        "trumpet",
        "Trumpet",
        "Teumpet",
        "trumpet",
        "Trumpet",
        "Trumpet",

        "Trumpet",

    ],
    "fife_img": [

        "Flute",
        "Flute",
        "Flute",

        "Flute",
        "Flute",
        "Flute",



        "Flute",
        "flute",
        "flute",


        "flute",
        "Flute",


        "Flute",

        "Flute",
    ],
    "piccolo_img": [

        "Flute",


        "Flute",

        "flute",
        "Flute",

        "flute",

        "Flute",


    ],
    "roto_drums_img": [

        "Drums",
        "Drums",
        "Drums",
        "Drums",
        "Drum",
        "DrumS",
        "Drums",

        "Drums",
        "Drums",


        "drums",


        "drums",


    ],
    "saxophone_img": [
        "Saxophone",
        "Sax",
        "Saxophone",
        "Saxofone",

        "Saxophone",


        "Saxo",
        "Saxiphone",
        "Saxophone",
        "saxophone",
        "saxophone",
        "Saxophone",

        "saxophone",
        "Saxophone",
        "Saxophone",
        "Saxophone",
        "Saxophone",
        "Saxophone",

        "Saxophone",
    ],
    "slit_drum_img": [

        "Xylophone",


        "Xylophone",

        "Xylophone",
        "Xilophone",


        "Xylophone",
        "Xylophone",
        "xylophone",
        "xylophone",
        "Xylophone",
        "Xilophone",

    ],
    "tambourine_img": [

        "Tambourine",
        "Tambourine",
        "Tamborine",

        "Tambourine",
        "Tambourine",
        "Tambourine fun",

        "Tamborine",

        "tambourine",
        "tambourine",

        "tambourine",

        "Tamborine",
        "Tambourine",

        "tamborine",

    ],
    "tenor_trombone_img": [
        "Trombone",
        "Trombone",
        "Trombone",
        "Trombone",

        "Trombone",
        "Trombone music",

        "Trombone",


        "trombone",
        "Trombón",

        "Trombone",

        "Trombone",

        "Trombone instrument",

        "Trompeta",

    ],
    "timpani_img": [
        "Drum",

        "Drum",

        "Drum",
        "Drum",

        "Drum",

        "Drum",
        "Drum",
        "Drum",
        "drum",
        "drum",
        "Drum",

        "drum",

        "Drum",

        "Drums",
    ],
    "triangle_img": [
        "Triangle",
        "Triangle",
        "Triangle",
        "Triangle (instrument)",

        "Triangle",
        "Triangle",

        "Triangle",
        "Triangle",
        "Triangle",
        "triangle",
        "triangle",
        "Triangle",

        "triangle",

        "Triangle",
        "Triangle",
        "Triangle",

    ],
    "trumpet_img": [
        "Trumpet",
        "Trumpet",
        "Trumpet",
        "Trumpet",

        "Trumpet",
        "Trumpet",



        "Trumpet",
        "Trumpet",
        "trumpet",

        "Trumpet",
        "Trumpet",
        "trumpet",
        "Trumpet",





    ],
    "3D_printer_img": [
        "3d printer",
        "3d printer",
        "3D Printer",
        "3D printer",
        "3d printer",
        "3d printer",

        "3d printer",

        "3D printer",
        "3D printer",


        "3D printer",
        "3d printer",

        "3d printen",
        "3d printer",


        "3D printer",



    ],
    "alienware_desktop_img": [
        "speaker",
        "Speaker",
        "Speaker",

        "speakers",
        "Speaker",
        "Speaker",
        "speaker",
        "speaker",
        "Speaker",
    ],
    "alienware_laptop_img": [

        "Laptop",
        "Laptop",


        "Laptop",

        "Laptop",
        "Laptop",
        "Laptop",
        "Laptop",

        "laptop",

        "Laptop",

        "laptop",

        "Laptop",
        "Laptop",
        "Lap top",
        "A laptop",
    ],
    "CRT_monitor_img": [

        "Computer monitor",

        "Old monitor",

        "monitor",


        "monitor",

        "Monitor",
        "Monitor",

        "monitor",

        "Monotor",
    ],
    "iMac_img": [

        "Apple computer",


        "Mac computer 🖥️",




        "Computer",

        "Computer",


        "computer",
        "Computer",
        "Monitor",

        "Apple computer",
    ],
    "LCD_monitor_img": [

        "Monitor",

        "Monitor",
        "Monitor",
        "monitor",


        "Monitor",



        "Monitor",

        "monitor",
        "Monitor",
        "Monitor",
        "Monitor",
        "monitor screen",
        "monitor",

    ],
    "mac_pro_img": [


        "mac pro",

        "Mac studio",

    ],
    "macbook_air_img": [

        "Laptop",
        "Laptop",




        "Laptop",
        "Laptop",
        "Laptop",
        "Laptop",

        "laptop",
        "laptop",
        "Laptop",
        "Laptop",
        "Laptop",
        "laptop",
        "laptop",


    ],
    "macbook_pro_img": [

        "Laptop",
        "Laptop",
        "Laptop",
        "Laptop",

        "Laptop",

        "Laptop",

        "Laptop",
        "Laptop",
        "Laptop",
        "laptop",
        "laptop",
        "Laptop",
        "Laptop",
        "Laptop",

        "laptop",

        "LapTop",
    ],
    "wired_keyboard_img": [
        "keyboard",
        "Keyboard",

        "Keyboard",

        "keyboard",
        "Keyboard",
        "keyboard",
        "Keyboard",
        "Keyboard",

        "Keyboard",

        "keyboard",
        "keyboard",
        "Keyboard",
        "Keyboard",
        "Keyboard",
        "keyboard",

        "Keyboard",
        "Keyboard",
    ],
    "mouse_img": [
        "mouse",
        "Mouse",

        "Mouse",

        "mouse",

        "mouse",
        "Mouse",
        "Mouse",
        "Mouse",


        "mouse",
        "mouse",
        "Mouse",
        "Mouse",
        "Mouse",
        "mouse",

        "Mouse",

        "Mause",
    ],
    "wireless_keyboard_img": [

        "Keyboard",

        "Keyboard",


        "Keyboard",
        "Keyboard",
        "Keyboard",
        "Keyboard",

        "keyboard",
        "keyboard",
        "Keyboard",
        "Keyboard",
        "Keyboard",

        "keyboard",


    ],
    "wireless_mouse_img": [
        "mouse",
        "Mouse",

        "Mouse",
        "Mouse",
        "mouse",

        "mouse",

        "Mouse",
        "Mouse",
        "Mouse",

        "mouse",
        "mouse",
        "Mouse",
        "Mouse",
        "Mouse",
        "mouse",


        "Mouse",
    ],
    "XPS_desktop_img": [

        "Personal Computer",

        "Pc old",

        "Pc tower",


        "PC",

        "Pc",

        "PC with Intel icore i7",
        "Pc",
    ],
    "XPS_laptop_img": [
        "laptop",
        "Laptop",
        "Laptop",
        "Laptop",

        "laptop",

        "laptop",
        "Laptop",

        "Laptop",

        "Laptop",
        "laptop",
        "laptop",
        "Laptop",
        "Laptop",
        "Laptop",

        "laptop",

        "Lap top",

        "A Laptop",
    ],
    "chainsaw_img": [

        "Chainsaw",
        "Chainsaw",
        "Chainsaw",
        "Chainsaw",
        "chainsaw",
        "Chainsaw",


        "Chainsaw",



        "chainsaw",
        "Chainsaw",
        "Chainsaw",
        "Chain saw",
        "chainsaw",

        "Chain saw",
        "Chainsaw",


        "Chainsaw",
    ],
    "chisel_img": [

        "Chisel",
        "Chisel",


        "chisel?",






        "Chisel",

        "Chisel",

        "groove chisel",

    ],
    "drain_shovel_img": [

        "Shovel",
        "Shovel",
        "Shovel",
        "Shovel",


        "shovel",

        "Shovel",

        "Shovel",
        "Shovel",

        "shovel",
        "Shovel",
        "Shovel",

        "shovel",


        "Shovel",
    ],
    "electric_pruner_img": [




        "Cutters",

        "Cutter",

        "cutter",


        "Cutter",

    ],
    "flat_brush_img": [
        "Paintbrush",

        "Paintbrush",
        "Paintbrush",
        "Paintbrush",
        "paint brush",

        "paintbrush",
        "Paintbrush",
        "Paint brush",

        "paintbrush",

        "Paint brush",

        "paint brush",


    ],
    "gardening_shear_img": [
        "clippers",

        "Clipper",
        "clippers",
        "Clippers",

    ],
    "glass_palette_img": [



        "Watercolors",

        "Water colors",
        "Watercolors",

        "water color pallette",
        "Water paint",
        "Watercolor pallet",

    ],
    "lopper_img": [

        "Cutter",

        "Branch cutter",



        "cutter",
        "cutter",



        "branch cutter",


    ],
    "mallet_img": [
        "mallet",

        "Mallet",

        "Mallet",
        "meat mallet",

        "mallet",
        "Mallet (meat tenderizer",


        "Meat mallet",


        "Mallet",





    ],
    "potting_trowel_img": [
        "shovel",
        "Mini shovel",

        "Small shovel",
        "Shovel for crops",
        "small shovel",

        "shovel",

        "Shovel",





        "Luh shovel",
        "Shovel",
        "small shovel",


        "Shovel",

    ],
    "rake_img": [
        "rake",
        "Rake",
        "Rake",
        "Rake",
        "Rake",
        "rakes",
        "Rake",
        "rake",
        "Rake",
        "Rake",
        "Rake",
        "Rake",
        "Rake",




        "Rake",

        "rake",
        "Rake",


    ],
    "rockery_trowel_img": [

        "Tool",

        "Carving tool",


        "Tool",





    ],
    "round_brush_img": [
        "paintbrush",

        "Paintbrush",
        "Paint brush",
        "Paintbrush",
        "paint brush",

        "paintbrush",
        "Paintbrush",
        "Paint brush",

        "paintbrush",

        "Paint brush",
        "Paint brush",
        "paint brush",
        "paint brush",

        "Paint brush",
    ],
    "rounded_point_shovel_img": [
        "shovel",
        "Shovel",
        "Shovel",
        "Shovel",
        "Shovel",
        "shovel",
        "Shovel",
        "shovel",

        "Shovel",

        "Shovel",
        "Shovel",

        "shovel",
        "Shovel",
        "Shovel",

        "shovel long",
        "shovel",

    ],
    "wire_img": [
        "wire",

        "Metal wire",
        "Wire",

        "wire",
        "Wire",
        "wire",
        "Wire",

        "Wire",
        "Wire",
        "Wire",
        "wire",

        "Wire",
        "Wire",
        "Wire",

        "wire",

    ]

    ,
    "wood_palette_img": [
        "paint palette",

        "Painter palette",

        "Paint pallet? 🎨 stuff to put paint on",
        "paint palette",


        "Paint palate",
        "Paint pallet",
        "Painter’s palette",

        "Palette",



        "Palette",

        "palette board",

    ],
    "apple_tree_img": [
        "Apple tree",

        "Apple tree",



        "Apple tree",
        "Apple tree",

        "Apple trees",
        "apple tree",

        "Apple tree",
        "Apple orchard",

        "Apple tree",
        "apple tree?",

        "apple tree",
        "apple tree",
        "apple trees",

        "Apple tree",
    ],
    "bulldog_img": [

        "bulldog",

        "bulldog",
        "Bulldog",

        "Bull Dog",

        "Bulldog",


        "Bulldog",
        "Bulldog",
        "bulldog",
        "Bulldog",

        "Bull dog",

        "bull dog",


        "Bulldog",

    ],
    "cedar_img": [
        "Tree",
        "tree",
        "Tree",
        "Big tree",

        "Tree",
        "Tree",

        "A middle age tree",

        "tree",

        "Tall tree",
        "Tall tree",
        "tree",
        "Tree",
        "tree",

        "tree",
        "Tall tree",

        "tree",
        "Tree",
    ],
    "dandelion_img": [

        "yellow flower",


        "Yellow flower",

        "Yellow flower",




        "Yellow flower",

        "Picture of an exotic, yellow flower",
        "yellow flower",
        "yellow flower",
        "Yellow flower",
    ],
    "Eagle_img": [
        "Eagle(Freedom)",
        "eagle",

        "eagle",
        "Eagle",
        "Eagle/bird",


        "Eagle",
        "Eigle",

        "eagle",
        "Eagle",
        "eagle",
        "An eagle",
        "eagle",

        "eagle",
        "eagle",

        "Eagle",
    ],
    "Edelweiss_img": [
        "Flower",

        "Flower",

        "Flower",
        "Flower",


        "Flower",



        "Flower",

        "flower",


    ],
    "german_shepherd_img": [
        "German Shepard",
        "german shephard",
        "Dog (german shepherd)",

        "german sheppard",

        "German shepherd",
        "Germán shepherd",
        "German shepherd",
        "German Shepard",
        "German sheperd",
        "German Shepherd",
        "German shepherd",
        "german shepherd",

        "shephard",
        "German shepherd",

        "German Shepard - dog",

        "German shepherd",
    ],
    "orange_tree_img": [
        "Orange tree",
        "orange tree",
        "Orange tree",
        "An Orange tree",
        "orange tree",
        "Orange tree",
        "Orange tree",
        "Orange tree",

        "Orange yree",
        "oranges tree",
        "Orange tree",
        "Orange tree",
        "Orange tree",
        "orange tree",
        "Orange tree",
        "orange tree",
        "Orange tree",
        "orange tree",
        "Orange Tree",
        "orange trees",
        "orange tree",
        "Orange tree",
    ],
    "Ostrich_img": [
        "Ostrich",
        "ostrich",
        "Ostrich",

        "ostrich",
        "Ostrich",

        "Ostrich",

        "Ostrich",
        "ostrich",

        "Ostrich",
        "Ostrich",
        "ostrich",
        "Ostrich",
        "ostrich",
        "Ostrich",
        "ostrich",
        "Ostrich",

        "ostrich",
        "Ostrich",
        "Ostrich",
        "an ostrich",
    ],
    "owl_img": [

        "owl",
        "Owl",

        "owl",
        "Owl",
        "Bird/owl",
        "Owl",

        "Owl",
        "owl",
        "Owl",
        "Owl",

        "owl",
        "Owl",
        "owl",
        "Owl",
        "owl",

        "owl",
        "owl",
        "Owl",
        "Owl",
    ],
    "penguin_img": [
        "Skipper(Penguin)",
        "penguin",
        "Penguin",

        "penguin",
        "Penguin",
        "Penguin",
        "Penguin",
        "Penguin",
        "Penguin",
        "Penguin",

        "Penguin",

        "penguin",
        "Penguin",
        "penguin",
        "Penguin",
        "penguin",

        "penguin",
        "pinguin",
        "Penguin",
    ],
    "persian_img": [

        "cat",
        "Cat",

        "cat",
        "Cat",
        "Cat",
        "Cat",

        "Cat",


        "cat",
        "Cat",
        "cat",
        "Cat",
        "cat",


        "fluffy cat",
        "Cat",
        "Ugly cat",
    ],
    "Pine_img": [
        "tree",

        "Tree",

        "tree (known for height)",
        "Tree",
        "Tree",
        "Tree",

        "tree",

        "Tree",
        "Tree",
        "tree",
        "Tree",
        "tree",

        "Tree",

        "tree",
        "Tree",
    ],
    "rose_img": [

        "Rose",

        "wet rose",
        "Red rose",
        "Rose",
        "Red rose",

        "Red rose",


        "Rose",

        "rose",
        "Wet rose",
        "rose",
        "Red rose",
        "flower",

        "red rose",
        "red rose",
        "Rose",
        "wet rose",
        "Rose",
    ],
    "siamese_img": [
        "Cat",
        "cat",
        "Cat",

        "cat",

        "Cat",

        "Cat",


        "cat",
        "Cat",
        "cat",

        "cat",


        "cat",
        "Cat",
    ],
    "tulip_img": [
        "Flower",
        "flower",
        "Flower (tulip)",

        "flower",

        "Flower",

        "Flower",
        "Flower",


        "flower",

        "flower",


        "Flower",
        "Flower",

    ],
    "cerberus_img": [

        "Cerberus",


        "Cerberus",


        "Cerbero",

        "Cerberus",

        "cerberus",
        "Cerberus",


        "Cerberus",


    ],
    "cherubim_img": [
        "Angel",
        "angel portray",
        "Angel",

        "Cherub/angel",
        "Angel",

        "Sweet Angel",
        "Angel",
        "angel",
        "Angel kid",

        "angel",
        "Angel",

        "Angel",


        "baby angel",
        "Angel",
    ],
    "drow_img": [
        "Dark elf",


        "elf",

        "Archer elf",

        "elf",


        "elf",

    ],
    "forest_elf_img": [
        "Elf",

        "Wood Elf",


        "Elf warrior",
        "Elf",

        "Elf lady in the woods",
        "elf",

        "Elf in forest",



    ],
    "golem_img": [
        "Golem",

        "Golem",
        "Golem",


        "golem",

        "golem",


        "golem",

        "Golem",


    ],
    "harpy_img": [
        "Harpy",

        "Harpy",


        "Harpy",



        "harpy",

        "Harpy",
        "Harpie",
        "harpies",


        "harpie or siren",
    ],

    "hellhound_img": [

        "fire breathing dog",


        "Fire dog",

        "Fiery dog",

        "Dog with fire mouth",
        "Fire breathing dog",
        "Dog breathing fire",

        "Fire-breathing dog",
        "dog barking flames",



    ],
    "hydra_img": [

      "Hydra",

         "hydra",


    ],
    "mermaid_img": [
        "Mermaid",

        "Mermaid",

        "mermaid",
        "Mermaid",
        "Mermaid",
        "Mermaid",


        "mermaid",
        "Mermaid",
        "Mermaid",
        "Mermaid",

        "Mermaid",
        "mermaid",



        "mermaid",
        "mermaid",
        "Mermaid",
        "Mermaid",

    ],
    "pegasus_img": [
        "Pegasus",

        "Pegasus",

        "pegasus",
        "Pegasus",

        "Pegasus",


        "Pegaso",
        "Pegasus",
        "Pegasus",
        "pegasus",
        "Pegasus",

        "Pegassus",
        "pegasus",


        "Pegasus",

    ],
    "phoenix_img": [
        "Pheonix",
        "phoenix",
        "Phoenix",

        "phoeniz",
        "Phoenix",


        "Phoenix",
        "Fenix",

        "Phoenix",
        "Pheonix",



        "Phoenix image",
        "pheonix",

        "phoenix",

    ],
    "thunderbird_img": [
        "eagle",

        "Eagle (griffon like)",

        "Eagle",

        "Eagle",

        "Eagle",


        "Eagle",

        "eagle",
        "Eagle",


        "eagle",



        "Eagle",
    ],
    "triton_img": [
        "Poseidon",

        "Poseidon",

        "poseidon",

        "Poseidon",
        "Poseidon",

        "Poseidon",

        "Poseidon",

        "poseidon",


        "Poseidon",


        "poseidon",

    ],
    "troll_img": [
        "Troll",

        "Troll",


        "Troll",


        "troll",

        "troll",
        "Troll",
        "troll",


        "Troll",


    ],
    "unicorn_img": [
        "unicorn",
        "unicorn",
        "Unicorn",

        "unicorn",
        "Unicorn",
        "Unicorn",
        "Unicorn",
        "Unicorn",
        "Unicorn",
        "unicorn",
        "Unicorn",
        "Unicorn",

        "unicorn",

        "unicorn",

        "unicorn",

        "unicorn",
        "unicorn",
        "Unicorn",
    ],
    "wyvern_img": [
        "dragon",
        "dragon",

        "dragon",
        "Dragon",
        "Dragon",
        "Dragon",

        "Dragon",



        "dragon",

        "dragon",

        "dragon",


        "dragon",

    ],
}


# =========================
# Normalization
# =========================
# Clean the dataframe labels
df['Image'] = df['Image'].str.strip().str.lower()

# Clean the correct_answers dictionary
correct_answers_normalized = {
    k.lower().strip(): [ans.lower().strip() for ans in v]
    for k, v in correct_answers.items()
}

# =========================
# Agreement Rate Calculation with Debugging
# =========================
image_agreement = {}
missing_images = []
unmatched_responses = {}

for image in df['Image'].unique():
    if image not in correct_answers_normalized:
        missing_images.append(image)
        continue

    image_df = df[df['Image'] == image]
    responses = image_df['Response'].dropna().str.strip().str.lower()

    acceptable_answers = correct_answers_normalized[image]

    agree_count = 0
    disagree_count = 0
    unmatched_resp = []

    for resp in responses:
        if resp in acceptable_answers:
            agree_count += 1
        else:
            disagree_count += 1
            unmatched_resp.append(resp)

    total = agree_count + disagree_count
    agreement_rate = (agree_count / total) * 100 if total > 0 else 0

    image_agreement[image] = {
        'Agreement %': agreement_rate,
        'Agree Count': agree_count,
        'Disagree Count': disagree_count,
        'Total Responses': total
    }

    if unmatched_resp:
        unmatched_responses[image] = Counter(unmatched_resp)

# =========================
# Chi-Square Test
# =========================
# Prepare contingency table
contingency_data = []
labels = []

for image, data in image_agreement.items():
    if data['Total Responses'] >= 5:  # Ensure enough sample size
        contingency_data.append([data['Agree Count'], data['Disagree Count']])
        labels.append(image)

# Run chi-square if we have enough images
if len(contingency_data) >= 2:
    chi2, p, dof, expected = chi2_contingency(contingency_data)

    print("\nChi-Square Test Results")
    print(f"Chi2 Statistic: {chi2}")
    print(f"p-value: {p}")
    print(f"Degrees of Freedom: {dof}")
    print(f"Expected Frequencies:\n{expected}")

    # Interpret
    alpha = 0.05
    if p < alpha:
        print("\nConclusion: There is a statistically significant difference in agreement rates across images (reject null hypothesis).")
    else:
        print("\nConclusion: No significant difference in agreement rates across images (fail to reject null hypothesis).")
else:
    print("\nNot enough images with sufficient responses to perform chi-square test.")

# =========================
# Outputs
# =========================
print("\nAgreement Rates per Image:")
for image, stats in image_agreement.items():
    print(f"{image}: {stats['Agreement %']:.2f}% (n={stats['Total Responses']})")

if missing_images:
    print("\nMissing Images from Dictionary:")
    print(missing_images)

if unmatched_responses:
    print("\nUnmatched Responses by Image:")
    for image, counts in unmatched_responses.items():
        print(f"{image}: {dict(counts)}")
# Out:
# Chi-Square Test Results
# Chi2 Statistic: 303.02481772263013
# p-value: 8.211922562844723e-24
# Degrees of Freedom: 94
# Expected Frequencies:
# [[12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [12.25578231 11.74421769]
#  [12.25578231 11.74421769]
#  [12.25578231 11.74421769]
#  [12.25578231 11.74421769]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [12.76643991 12.23356009]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [12.76643991 12.23356009]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.23446712 10.76553288]
#  [12.76643991 12.23356009]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [10.72380952 10.27619048]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [12.25578231 11.74421769]
#  [13.27709751 12.72290249]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [11.23446712 10.76553288]
#  [11.23446712 10.76553288]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [10.72380952 10.27619048]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.76643991 12.23356009]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [12.76643991 12.23356009]
#  [11.74512472 11.25487528]
#  [12.76643991 12.23356009]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [12.25578231 11.74421769]
#  [13.27709751 12.72290249]
#  [12.76643991 12.23356009]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.76643991 12.23356009]
#  [12.25578231 11.74421769]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]
#  [12.25578231 11.74421769]
#  [12.76643991 12.23356009]
#  [11.74512472 11.25487528]
#  [11.74512472 11.25487528]]
#
# Conclusion: There is a statistically significant difference in agreement rates across images (reject null hypothesis).
#
# Agreement Rates per Image:
# brocolli_img: 87.50% (n=24)
# carrot_img: 78.26% (n=23)
# cauliflower_img: 73.91% (n=23)
# chicken_breast_img: 27.27% (n=22)
# apple_img: 36.36% (n=22)
# ham_slice_img: 56.52% (n=23)
# mcintosh_apple_img: 54.17% (n=24)
# moon_drop_grape_img: 27.27% (n=22)
# pork_sausage_img: 65.22% (n=23)
# red_globe_grape_img: 56.52% (n=23)
# ribeye_steak_img: 34.78% (n=23)
# salmon_fillet_img: 50.00% (n=24)
# sweet_potato_img: 58.33% (n=24)
# t_bone_steak_img: 29.17% (n=24)
# tuna_steak_img: 37.50% (n=24)
# turkey_breast_img: 20.83% (n=24)
# bass_trombone_img: 45.45% (n=22)
# bell_img: 68.18% (n=22)
# bongo_drums_img: 32.00% (n=25)
# castanets_img: 50.00% (n=22)
# clarinet_img: 52.17% (n=23)
# cornet_img: 63.64% (n=22)
# fife_img: 56.52% (n=23)
# piccolo_img: 26.09% (n=23)
# roto_drums_img: 47.83% (n=23)
# saxophone_img: 75.00% (n=24)
# slit_drum_img: 43.48% (n=23)
# tambourine_img: 54.17% (n=24)
# tenor_trombone_img: 52.00% (n=25)
# timpani_img: 60.87% (n=23)
# triangle_img: 72.73% (n=22)
# trumpet_img: 60.87% (n=23)
# 3d_printer_img: 58.33% (n=24)
# alienware_desktop_img: 40.91% (n=22)
# alienware_laptop_img: 56.00% (n=25)
# crt_monitor_img: 34.78% (n=23)
# imac_img: 45.45% (n=22)
# lcd_monitor_img: 54.55% (n=22)
# mac_pro_img: 9.52% (n=21)
# macbook_air_img: 56.52% (n=23)
# macbook_pro_img: 65.22% (n=23)
# wired_keyboard_img: 73.91% (n=23)
# mouse_img: 66.67% (n=24)
# wireless_keyboard_img: 52.17% (n=23)
# wireless_mouse_img: 72.73% (n=22)
# xps_desktop_img: 31.82% (n=22)
# xps_laptop_img: 70.83% (n=24)
# chainsaw_img: 57.69% (n=26)
# chisel_img: 27.27% (n=22)
# drain_shovel_img: 59.09% (n=22)
# electric_pruner_img: 21.74% (n=23)
# flat_brush_img: 50.00% (n=22)
# gardening_shear_img: 18.18% (n=22)
# glass_palette_img: 26.09% (n=23)
# lopper_img: 22.73% (n=22)
# mallet_img: 36.36% (n=22)
# potting_trowel_img: 47.83% (n=23)
# rake_img: 69.57% (n=23)
# rockery_trowel_img: 13.64% (n=22)
# round_brush_img: 63.64% (n=22)
# rounded_point_shovel_img: 69.57% (n=23)
# wire_img: 70.83% (n=24)
# wood_palette_img: 47.62% (n=21)
# apple_tree_img: 65.22% (n=23)
# bulldog_img: 50.00% (n=24)
# cedar_img: 73.91% (n=23)
# dandelion_img: 34.78% (n=23)
# eagle_img: 62.50% (n=24)
# edelweiss_img: 30.43% (n=23)
# german_shepherd_img: 69.57% (n=23)
# orange_tree_img: 95.65% (n=23)
# ostrich_img: 80.00% (n=25)
# owl_img: 79.17% (n=24)
# penguin_img: 82.61% (n=23)
# persian_img: 62.50% (n=24)
# pine_img: 65.22% (n=23)
# rose_img: 72.00% (n=25)
# siamese_img: 52.17% (n=23)
# tulip_img: 44.00% (n=25)
# cerberus_img: 30.43% (n=23)
# cherubim_img: 60.87% (n=23)
# drow_img: 20.83% (n=24)
# forest_elf_img: 29.17% (n=24)
# golem_img: 26.92% (n=26)
# harpy_img: 32.00% (n=25)
# hellhound_img: 34.78% (n=23)
# hydra_img: 26.09% (n=23)
# mermaid_img: 64.00% (n=25)
# pegasus_img: 54.17% (n=24)
# phoenix_img: 52.17% (n=23)
# thunderbird_img: 43.48% (n=23)
# triton_img: 41.67% (n=24)
# troll_img: 32.00% (n=25)
# unicorn_img: 78.26% (n=23)
# wyvern_img: 47.83% (n=23)
#
# Unmatched Responses by Image:
# brocolli_img: {'green brocolo': 1, 'brócoli food': 1, 'broccoli sliced in half lengthwise': 1}
# carrot_img: {'small carrots': 1, 'bugs bunny': 1, 'organic carrots': 1, 'wortel': 1, 'carrot bunch': 1}
# cauliflower_img: {'coliflor': 2, 'delicious coliflower': 1, 'i like that coliflawer': 1, 'cawliower': 1, 'bloemkool': 1}
# chicken_breast_img: {'chicken': 6, 'raw chicken': 3, 'breast of xhicken': 1, 'chiken for me': 1, 'chicken fillet': 2, 'raw white meat': 1, 'raw chicken breast': 1, 'uncooked chicken breast': 1}
# apple_img: {'green apple': 7, 'granny smith apple': 2, 'one a day keeps the doctor away': 1, 'apple machine': 1, 'one and half apple': 1, 'granny smith': 1, 'granny smith apple sliced lengthwise': 1}
# ham_slice_img: {'jam': 2, 'delicious ham': 1, 'english ham': 1, 'slice of ham': 1, 'smoked ham': 1, 'ham slice': 2, 'meat slice': 1, 'processed ham slice': 1}
# mcintosh_apple_img: {'red apple': 8, 'red smith apple': 1, 'snow apple': 1, 'an apple': 1}
# moon_drop_grape_img: {'eggplant': 3, 'some berry or a type of fruit': 1, 'long grapes': 2, 'look like grapes': 1, 'red wine': 1, 'artichoke': 1, 'berry': 1, 'java plums': 1, 'aubergines': 1, 'grape-like fruit': 1, 'kurma': 1, 'black grapes': 1, 'black sapphire grapes': 1}
# pork_sausage_img: {'raw sausages': 1, 'sausage chorizo': 1, 'bar b q': 1, 'chorizo': 3, 'argentiniam chirizos': 1, 'uncooked sausages': 1}
# red_globe_grape_img: {'red grapes': 4, 'chilean grapes': 1, 'red wine': 1, 'red globe\ngrapes': 1, 'bunch of grapes': 1, 'red globe grapes': 1, 'red grape': 1}
# ribeye_steak_img: {'meat': 4, 'cow meat': 1, 'red meat probably cow': 1, 'nice cut of meat': 1, 'asado for argentina': 1, 'loin': 1, 'beef': 1, 'fine steak': 1, 'meat slice': 1, 'raw steak': 1, 'ribeye steak': 1, 'raw meat': 1}
# salmon_fillet_img: {'raw salmon': 2, 'fresh salmon': 2, 'rich salmon': 1, 'tuna': 1, 'salmon filet': 1, 'salmon fillet': 3, 'sashimi': 1, 'uncooked salmon': 1}
# sweet_potato_img: {'camote': 2, 'sweet potato i think so': 1, 'potato': 3, 'potatoes': 2, 'cassave': 1, 'red potatoes': 1}
# t_bone_steak_img: {'raw meat': 3, 'steak': 6, 'a different piece of meat': 1, 'meat': 2, 't bone': 1, 'raw red meat': 1, 'lamb': 1, 'carne': 1, 'a beef cut': 1}
# tuna_steak_img: {'meat': 3, 'fish': 2, 'raw tuna': 1, 'fresh piece of tuna': 1, 'fresh tuna': 1, 'salmon': 1, 'uncooked tuna': 2, 'fine meat': 1, 'raw meat': 2, 'tuna fillet': 1}
# turkey_breast_img: {'bread': 1, 'turkey': 1, 'chicken': 3, 'pork loin': 1, 'cooked turkey': 1, 'chicken ready to eat': 1, 'thanks given': 1, 'turkey breast': 1, 'roasted turkey': 1, 'roasted chicken breast': 1, 'roastes pork': 1, 'roast chicken': 1, 'grilled chicken': 1, 'slices of cooked chicken': 1, 'meat': 1, 'chancho': 1, 'cooked ham of some sort': 1}
# bass_trombone_img: {'bass trombone': 1, 'trumpet': 4, 'another trumpet': 1, 'brass instrument': 2, 'trompeter': 1, 'sliding trumpet': 1, 'trombón': 1, 'clarinete': 1}
# bell_img: {'metal bell': 1, 'campaing': 1, 'small bell': 1, 'jingle bell': 1, 'romging bell': 1, 'church bell': 1, 'dinner bell': 1}
# bongo_drums_img: {'deum': 1, 'congas': 1, 'a kid of drum': 1, 'like drum': 1, 'african drums': 1, 'drums': 3, 'african drum': 1, 'bongo drums': 2, 'percussion instruments': 1, 'pair of drums': 1, 'music instruments': 1, 'kendang': 1, 'drumset': 1, 'two drums': 1}
# castanets_img: {'instrument': 1, 'wood instrument': 1, 'spanish music': 1, 'chocolate': 1, 'marroccas': 1, "machaka's": 1, 'clackers': 1, 'wooden instrument': 2, 'wooden sculpture': 1, 'a toy': 1}
# clarinet_img: {'flute': 6, 'bassoon': 1, 'another flute': 1, 'music of scotland': 1, 'flute thing': 1, 'oboe': 1}
# cornet_img: {'cornet': 1, 'again instrument': 1, 'mini trompet': 1, 'another wind instrument': 1, 'band of music': 1, 'tuba': 2, 'horn instrument': 1}
# fife_img: {'pencil': 1, 'recorder': 3, 'english flute': 1, 'pen': 2, 'musical instrument': 1, 'suling': 1, 'black metal flute': 1}
# piccolo_img: {'?': 1, 'traverse flute': 1, 'instrument': 1, 'piccolo': 2, 'like a flute maybe': 1, 'difficult instrument': 1, 'irish music': 1, 'clarinete': 1, 'bassoon': 1, 'a clarinet like music instrument.': 1, 'air musical\ninstrument': 1, 'music instrument': 1, 'metal flute': 1, 'short flute': 1, 'recordee': 1, 'wind instrument of some sort': 1}
# roto_drums_img: {'?': 1, 'salsa music': 1, 'drumset': 1, 'a form of drum stand': 1, 'battery': 1, 'piar of drums': 1, 'stand': 1, 'percussion': 2, 'percussion instrument': 1, 'snare drums': 1, 'cymbals': 1}
# saxophone_img: {'jazz': 1, 'alto saxophone': 1, 'shiny saxofone': 1, 'my trumpet sounds': 1, 'golden saxophone': 1, 'trumpet': 1}
# slit_drum_img: {'drum type': 1, 'instrument': 2, 'percussion instrument': 1, 'i don’t know': 1, 'it is an organ': 1, 'piano': 1, 'strange percussion instrument': 1, 'music instrument': 1, 'musical instrument': 1, 'wood block xylophone': 1, 'files': 1, 'marimba': 1}
# tambourine_img: {'drum': 2, 'itrsument': 1, 'abba': 1, 'pandereta': 2, 'hand thingie': 1, 'pandereen': 1, 'music instrument': 1, 'rebana': 1, 'bongo': 1}
# tenor_trombone_img: {'instrument': 1, 'i don’t remember': 1, 'orchestra symphony': 1, 'instrumento viento': 1, 'trumpet': 2, 'a trumpet': 1, 'musical instrument': 1, 'wind instrument': 1, 'brass instrument': 1, 'instrumento musical': 1, 'saxophone': 1}
# timpani_img: {'conga': 1, 'kettle drum': 1, 'timpani': 1, 'latin music': 1, 'bongo': 1, 'music instrument': 1, 'kendang': 1, 'single percussion instrument': 1, 'bongo drum': 1}
# triangle_img: {'instrument triangle': 1, 'idk': 1, 'school music': 1, 'musical triangle': 1, 'music instrument': 1, 'triangle musical instrument': 1}
# trumpet_img: {'wind instrument': 1, 'bright trumpet': 1, 'music': 1, 'saxofón': 1, 'trombone': 2, 'trumpt': 1, 'horn instrument': 1, 'saxophone': 1}
# 3d_printer_img: {'water filter': 1, 'plumbing equipment': 1, 'oven': 1, 'current meter': 1, 'printer': 1, 'toolbox': 1, 'scale': 1, 'vase': 1, 'unknown machine': 1, 'a class vase': 1}
# alienware_desktop_img: {'pc': 1, 'alienware pc': 1, 'desktop?': 1, 'wireless speaker': 1, 'tv box pt. 2': 1, 'speaker amplifier': 1, 'adapter': 1, 'cpu': 1, 'hub': 1, 'computer': 1, 'loudspeaker': 1, 'amplifier/audiotool': 1, 'multipurpose speaker': 1}
# alienware_laptop_img: {'gamer computer': 1, 'gaming laptop': 6, 'alienware laptop': 1, 'gaming computer': 1, 'gamming laptop': 1, 'gamer laptop': 1}
# crt_monitor_img: {'1st macintosh': 1, 'old screen': 1, 'old pc monitor': 1, 'old computer monitor': 2, 'macintosh edition 1': 1, 'computer': 2, 'computer,': 1, 'pc desktop': 1, 'screen': 2, 'crt old monitor': 1, 'old pc screen': 1, 'old laptop screen': 1}
# imac_img: {'mac screen': 1, 'imac': 1, 'desktop computer': 1, 'imac??': 1, 'apple monitor': 2, 'macbook': 1, 'mac desktop': 2, 'pc screen': 1, 'screen': 1, 'apple mac screen': 1}
# lcd_monitor_img: {'screen': 4, 'lcd monitor': 1, 'smart tv': 1, 'computer': 1, 'pc screen': 2, 'computer screen': 1}
# mac_pro_img: {'memory': 1, '😀': 1, 'apple pc': 1, 'apple computer': 1, 'mac overprices cheese grader': 1, 'no idea': 2, 'hard drive': 1, 'fan': 1, 'tv box': 1, 'computer tower': 1, 'grater': 1, '.': 1, 'vegetable grater': 1, 'pc': 1, 'cheese shredder': 1, 'rub': 1, 'nop': 1, 'cheese grater': 1}
# macbook_air_img: {'mac': 2, 'macbook pro': 1, 'macbook air': 1, 'macbook': 2, 'mac laptop': 2, 'silver laptop': 1, 'computer': 1}
# macbook_pro_img: {'mac': 2, 'macbook pro': 2, 'macbook': 1, 'unbranded laptop': 1, 'a turned off laptop': 1, 'lap\ntop': 1}
# wired_keyboard_img: {'wired keyboard': 2, 'old pc keyboard': 1, 'computer keyboard': 1, 'hard-wired keyboard': 1, 'regular pc keyboard': 1}
# mouse_img: {'wired mouse': 3, '🐁': 1, 'chord mouse': 1, 'mouse w wire': 1, 'hard-wired mouse': 1, 'cable mouse': 1}
# wireless_keyboard_img: {'keyboard apple': 1, 'wireless keyboard': 4, 'mac keyboard': 3, 'apple keyboard': 1, 'key pad': 1, 'a keyboard': 1}
# wireless_mouse_img: {'wireless mouse': 4, 'knife sharoener': 1, 'bluetooth mouse': 1}
# xps_desktop_img: {'memory': 1, 'cpu': 2, 'computer': 3, 'desktop': 2, 'hard drive': 1, 'ups box': 1, 'tv box': 1, 'pc processor': 1, 'computer tower': 2, 'server system unit': 1}
# xps_laptop_img: {'dell laptop': 2, 'laptop pc': 1, 'computer': 1, 'laptop computer': 1, 'windows laptop': 1, 'a laptop displaying entertainment games and apps': 1}
# chainsaw_img: {'saw': 3, 'electric saw': 2, 'electric hand saw': 1, 'trimmer': 1, 'small chainsaw': 1, '.': 1, 'hedge trimmer': 1, 'tree branch chainsaw': 1}
# chisel_img: {'shovel (small)': 2, 'tool': 1, 'pt something for crops': 1, 'carving tool': 1, 'shovel for weeding': 1, 'shovel': 1, 'carpentry tool': 1, 'digger': 1, 'mini shovel': 1, '.': 1, 'gardening tool': 1, 'luh shank': 1, 'sweveel': 1, 'carpenter tool': 1, 'hammer': 1}
# drain_shovel_img: {'long shovel': 1, 'shovel (planting)': 1, 'deep shovel': 1, 'shovel for bulbs': 1, 'lamp': 1, '.': 1, 'spade': 1, 'transplanting shovel': 1, 'narrow shovel': 1}
# electric_pruner_img: {'clipper': 2, 'garden scissor': 1, 'branch cutter': 1, 'au mrd imaginate poner tu chula ahi jajja': 1, 'pruner': 1, 'clippers': 1, 'plant scissors': 1, 'wood cutting scissors': 1, 'small branch trimmer': 1, 'garden cutter': 1, 'schaar': 1, 'pruning shears': 1, 'trimmer in forest': 1, 'pruning sheers': 1, 'flower scissors': 1, 'a cutting tool in a cut tree': 1, 'sicers': 1}
# flat_brush_img: {'brush': 7, 'art brush': 1, 'oil pain brush': 1, 'artist paintbrush': 1, 'penil': 1}
# gardening_shear_img: {'cutter': 4, 'garden scissor': 1, 'branch cutter': 1, 'plyers': 1, 'pruner': 1, 'plant scissors': 1, 'cut stems': 1, 'pliers': 1, 'small branch trimmer': 1, 'schaar': 1, 'scissor': 1, 'trimmer': 1, 'metal sheers': 1, 'flower scissors': 1, 'pruning shears': 1}
# glass_palette_img: {'paint palette': 3, 'paint': 2, 'acrylic paint': 1, 'colors to paint': 1, 'used paint mixer': 1, 'paint pallet': 1, 'square palette': 1, '.': 1, 'color plate': 1, 'palet dirty': 1, 'paint holder': 1, 'color box': 1, 'oil mix board': 1, 'color palette': 1}
# lopper_img: {'clippers': 2, 'large garden scissor': 1, 'lil branch snapper': 1, 'pruner': 1, 'metal clipper': 1, 'hedge trimmers': 1, 'shears': 1, 'pliers': 1, 'trimmer': 2, 'branch trimmer': 1, 'schaat': 1, 'cable cutter': 1, 'tongs': 1, 'fence cutter': 1, 'alicate': 1}
# mallet_img: {'hammer': 4, 'kitchen hammer': 1, 'pounder': 1, 'meat tenderizer': 3, '.': 1, 'meat hammer': 2, 'meat slicer': 1, 'potato masher': 1}
# potting_trowel_img: {'garden spade': 1, 'gardening hand shovel': 1, 'spade': 2, 'gardening shovel': 2, 'garden shovel': 1, '.': 1, 'soil digger': 1, 'schep': 1, 'gardening trowel': 1, 'lampa': 1}
# rake_img: {'.': 1, 'soil loosener': 1, 'hark': 1, 'hoe': 1, 'farm tool': 1, 'steel rake': 1, 'trinche': 1}
# rockery_trowel_img: {'seed shovel': 1, 'whatasigma?': 1, 'idk': 1, 'rockery troad': 1, '-': 1, 'shovel': 1, 'seed hole digger': 1, 'rock shovel': 1, 'to plant seeds': 1, 'shovel for putting seeds': 1, '.': 1, 'soil scrapper': 1, 'yoga thing': 1, 'shank': 1, 'weed cutter': 1, 'some kind knife': 1, 'gardening tool': 1, 'no idea': 1, 'drainage stick': 1}
# round_brush_img: {'brush': 5, 'art brush': 1, 'kwast': 1, 'fine artist paintbrush': 1}
# rounded_point_shovel_img: {'shovel for garden': 1, 'lamp': 1, '.': 1, 'spade': 1, 'plain shovel': 1, 'lampa': 1, 'a shovel for digging': 1}
# wire_img: {'cable': 1, 'metal cord': 1, 'lead wire': 1, 'steel wire': 1, 'steel cable': 1, 'metal cable': 1, 'a cable': 1}
# wood_palette_img: {'stencil': 1, 'padlet': 1, 'art paint mixer': 1, 'paint basel': 1, 'paint mixer': 1, '.': 1, 'color palette': 1, 'palet': 1, 'paint holder': 1, 'painting board': 1, 'painter board': 1}
# apple_tree_img: {'tomato tree': 1, 'natural fruit': 1, 'orchard': 1, 'pomegranate tree': 1, 'productive orchard': 1, '0,5': 1, 'fruit tree': 1, 'tree': 1}
# bulldog_img: {'dog': 6, 'dog (el perro d babieca)': 1, 'strenght': 1, 'ugly sof': 1, 'dog with noise': 1, 'pit bull': 1, 'beefed dog': 1}
# cedar_img: {'oak?': 1, 'pine tree': 3, 'tree with huge leaves': 1, 'big cedar': 1}
# dandelion_img: {'flower': 8, 'life': 1, 'bright flower': 1, 'dendelion': 1, 'marigold': 2, 'dandelion': 2}
# eagle_img: {'eagle, bald': 1, 'observer': 1, 'bald eagle': 5, 'american eagle': 1, 'an eagle in flight': 1}
# edelweiss_img: {'dangerous plant': 1, 'unreal': 1, 'fuzzy flower': 2, 'strange flower': 1, 'wood flower': 1, 'trange flower': 1, 'molded flower': 1, 'moldy flower': 1, 'plant?': 1, 'edelweis': 1, 'edelweiss': 1, 'picture of an exotic flower': 1, 'white flower': 2, 'white plant': 1}
# german_shepherd_img: {'intelligent': 1, 'dog': 5, 'hunter dog': 1}
# orange_tree_img: {'sevilla’s oranges': 1}
# ostrich_img: {'great runner': 1, 'bird': 1, 'long legged ostrich': 1, 'big bird that runs': 1, 'featherless ostrich': 1}
# owl_img: {'hoot hoot': 1, 'the observer': 1, 'ugly owl': 1, 'eagle owl': 1, 'picture of a curious owl': 1}
# penguin_img: {'freedom': 1, 'penguin wanting to hug or balance': 1, 'emperor penguin': 1, 'flapping, proud penguin': 1}
# persian_img: {'garfield': 1, 'personality': 1, 'cute kitten': 1, 'organge cat': 1, 'saggy cheeked cat': 1, 'persian cat': 2, 'fury, curious cat, real life garfield': 1, 'yellow cat': 1}
# pine_img: {'long thin tree': 1, 'natural disability': 1, 'naked tree': 1, 'pine tree': 2, 'thin tree': 1, 'big tree background mountains': 1, 'tall tree': 1}
# rose_img: {'red flower': 2, 'reborn': 1, 'morning rose': 1, 'aesthetic picture': 1, 'raindrops on roses': 1, 'rose in morning dew': 1}
# siamese_img: {'elegance': 1, 'persian cat': 1, 'siamese cat': 5, 'pretty cat with blue eyes': 1, 'siamese like cat': 1, 'skinny white cat with a strange look on its face': 1, 'white cat': 1}
# tulip_img: {'datalle': 1, 'tulip': 8, 'exotic flower': 1, 'spiky tulip': 1, 'an orange tulip but spikey': 1, 'flower and petals': 1, 'orange tulip': 1}
# cerberus_img: {'a three headed dog in a cave with a man in his paw': 1, 'portray': 1, 'hell': 1, 'mythical character': 1, '3 head monster': 1, 'monster': 1, 'three head monster': 1, 'three headed dog': 1, 'scary': 1, 'a 3 headed dog': 1, 'dog with 3 heads': 1, 'a three headed dog': 1, 'drawing of a three headed dog in a cave': 1, 'three-headed monster': 1, 'dog': 1, 'three headed animal': 1}
# cherubim_img: {'guardian': 1, 'winged baby': 1, 'cherub': 1, 'baby seraphin': 1, 'seraphim': 1, 'toddler with wings': 1, 'querubin': 1, 'old painting of a baby angel': 1, 'holy baby': 1}
# drow_img: {'cartoon character': 1, 'elven archer': 1, 'galactic war': 1, 'anime character': 1, 'artemis': 1, 'soldier': 1, 'archer': 3, 'fiction image': 1, 'alien elf': 1, 'game background': 1, 'the enemy of the before elf lady': 1, 'woman with bow': 1, 'elf-robot with bow and arrow': 1, 'drawing of a mystical female warrior': 1, 'shooter': 1, 'woman': 1, 'evil princess': 1}
# forest_elf_img: {'archer': 4, 'fantasy warrior': 1, 'archer shooting a bow in a forest': 1, 'elven ranger': 1, 'soldier and arrow': 1, 'robin hood': 1, 'arrow fighter': 1, 'arrow throwing fairy': 1, 'blond elf archer': 1, 'elven archer': 1, 'female archer in forrest': 1, 'cartoon elf shooting a bow and arrow in the forest': 1, 'hunter in forest': 1, 'warrior': 1}
# golem_img: {'cartoon character': 1, 'la mole but roblox': 1, 'cómics': 1, 'groot': 1, 'stone golem': 1, 'rock person': 1, 'stone man': 2, 'rock man!': 1, 'rock man': 3, 'rock figure': 1, 'rockman': 1, 'stone giant': 1, 'cartoon of rock man from the fantastic four': 1, 'clay giant': 1, 'ben grimm': 1, 'hulk': 1}
# harpy_img: {'cartoon character': 1, 'spell': 1, 'mythical character': 1, 'a bird with a human face and weird ears': 1, 'birdwoman': 1, 'weird human bird': 1, 'mythical figure': 1, 'creature?': 1, 'bird woman': 1, 'bird with human head': 1, 'mythical creature': 1, 'pheonix': 1, 'angry bird lady': 1, 'woman like eagle': 1, 'woman owl': 1, 'woman bird': 1, 'phoenix': 1}
# hellhound_img: {'hell hound': 1, 'cartoon character': 1, 'rodents of unusual size (rous) from the princess bride': 1, 'violent': 1, 'hellhound': 1, 'dragon or dog spitting out fire': 1, 'fiery cat': 1, 'mythological dog': 2, 'angry dog': 1, 'cerbero': 1, 'black and white cartoon of a fire breathing dog': 1, 'dragon with fire': 1, 'hot wolf': 1, 'wolf': 1}
# hydra_img: {'dragon': 4, 'work team': 1, 'greek mythology': 1, '7 head monsters looks like dragons': 1, '7 headed dragon': 2, 'wild dragons': 1, 'multiheaded dragon': 1, 'idra': 1, 'multiple headed creature': 1, 'dragon with 8 heads': 1, 'multi headed dragon': 1, 'drawing of a many headed dragon.': 1, '7-headed dragon': 1}
# mermaid_img: {'little mermaid': 1, 'a meeting': 1, 'young mermaid': 1, 'siren': 4, 'drawing of a mermaid': 1, 'mermaid drawing': 1}
# pegasus_img: {'angel horse': 1, 'powerful': 1, 'horse with wings': 3, 'flying horse': 2, 'centaur': 1, 'unicorn': 1, 'winged horse': 1, 'strong unicorn': 1}
# phoenix_img: {'respect': 1, 'huge bird': 1, 'mythical bird': 2, 'bird on fire!': 1, 'his feet are burning': 1, 'dragon': 1, 'mythical creature': 1, 'drawing of a bird with flames in the background': 1, 'drawing of a phoenix': 1, 'mockingjay': 1}
# thunderbird_img: {'owl': 1, 'family crest': 1, 'phoenix?': 1, 'bird': 1, 'mean eagle': 1, 'falco': 1, 'logo': 1, 'angry bird': 1, 'drawing of a bird': 1, 'eagle emblem': 1, 'bird as a symbol': 1, 'fierce eagle': 1, 'mythical bird': 1}
# triton_img: {'king triton?': 1, 'respectable myth': 1, 'triton': 1, 'god of the seas': 1, 'neptun': 1, 'mermaid king': 1, 'king triton': 2, 'merman king': 1, 'merman': 1, 'neptune': 1, 'drawing of neptune': 1, 'zeus': 1, 'aquaman greek god': 1}
# troll_img: {'cartoon character': 1, 'precarriousness': 1, 'ogor': 1, 'ogre': 3, 'ugly monster': 1, 'caveman': 3, 'opps': 1, 'goblin': 4, 'drawing of an angry ogre': 1, 'giant monster': 1}
# unicorn_img: {'lethal weapon': 1, 'a silly looking unicorn': 1, 'ugly unicorn': 1, 'unicorn drawing': 1, 'drawing of a unicorn': 1}
# wyvern_img: {'wyvern': 2, 'misterio': 1, 'wild fake dragon': 1, 'yellow dragon': 3, 'a yellow dragon like an icon/logo': 1, 'gold dragon': 1, 'dragon drawing': 1, 'dragon on a flag': 1, 'dragon symbol': 1}
